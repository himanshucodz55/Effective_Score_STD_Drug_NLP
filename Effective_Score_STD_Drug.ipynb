# %%
# Regression
import tensorflow
from sklearn.linear_model import LinearRegression, Ridge, ElasticNet, Lasso
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, BaggingRegressor, ExtraTreesRegressor, GradientBoostingRegressor, RandomForestRegressor, VotingRegressor
from sklearn.metrics import mean_squared_error as mse

import xgboost as xgb
import lightgbm as lgb
import catboost as cat

from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np

# %%
import os
print(os.listdir('../dataset'))
# Out:
# ['.ipynb_checkpoints', 'catboost_info', 'std-hyperopt-stacking.ipynb', 'test.csv', 'train.csv']

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    patient_id              name_of_drug             use_case_for_drug  \
# 0      206461                 Valsartan  Left Ventricular Dysfunction
# 1       95260                Guanfacine                          ADHD
# 2       92703                    Lybrel                 Birth Control
# 3       35696  Buprenorphine / naloxone             Opiate Dependence
# 4      155963                    Cialis  Benign Prostatic Hyperplasia
#
#                                    review_by_patient  effectiveness_rating  \
# 0  "It has no side effect, I take it in combinati...                     9
# 1  "My son is halfway through his fourth week of ...                     8
# 2  "I used to take another oral contraceptive, wh...                     5
# 3  "Suboxone has completely turned my life around...                     9
# 4  "2nd day on 5mg started to work with rock hard...                     2
#
#   drug_approved_by_UIC  number_of_times_prescribed  base_score
# 0            20-May-12                          27    8.022969
# 1            27-Apr-10                         192    7.858458
# 2            14-Dec-09                          17    6.341969
# 3            27-Nov-16                          37    6.590176
# 4            28-Nov-15                          43    6.144782

# %%
min_rating = train.effectiveness_rating.min()
max_rating = train.effectiveness_rating.max()

def scale_rating(rating):
    # Sacling from (1,10) to (0,5) and then replacing 0,1,2 in ratings with 0 (poor) and 3,4,5 with 1 (good).
    rating -= min_rating
    rating = rating/(max_rating - 1)
    rating *= 3
    rating = int(round(rating,0))
    return rating

train['new_effect_score'] = train.effectiveness_rating.apply(scale_rating)
test['new_effect_score'] = test.effectiveness_rating.apply(scale_rating)

# %%
train.head()
# Out:
#    patient_id              name_of_drug             use_case_for_drug  \
# 0      206461                 Valsartan  Left Ventricular Dysfunction
# 1       95260                Guanfacine                          ADHD
# 2       92703                    Lybrel                 Birth Control
# 3       35696  Buprenorphine / naloxone             Opiate Dependence
# 4      155963                    Cialis  Benign Prostatic Hyperplasia
#
#                                    review_by_patient  effectiveness_rating  \
# 0  "It has no side effect, I take it in combinati...                     9
# 1  "My son is halfway through his fourth week of ...                     8
# 2  "I used to take another oral contraceptive, wh...                     5
# 3  "Suboxone has completely turned my life around...                     9
# 4  "2nd day on 5mg started to work with rock hard...                     2
#
#   drug_approved_by_UIC  number_of_times_prescribed  base_score  \
# 0            20-May-12                          27    8.022969
# 1            27-Apr-10                         192    7.858458
# 2            14-Dec-09                          17    6.341969
# 3            27-Nov-16                          37    6.590176
# 4            28-Nov-15                          43    6.144782
#
#    new_effect_score
# 0                 3
# 1                 2
# 2                 1
# 3                 3
# 4                 0

# %%
import nltk
# nltk.download()
# nltk.download('averaged_perceptron_tagger')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
#     print(text)
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
#     print(text)
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
#     print(text)
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
#     print(text)
    # pos tag text
    pos_tags = pos_tag(text)
   
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
#     print(text)
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
#     print(text)
    text = " ".join(text)
#     print(text)
    return(text)

# clean text data
train["review_by_patient"] = train["review_by_patient"].apply(lambda x: clean_text(x))

# %%
train["review_by_patient"].head(20)
# Out:
# 0     side effect take combination bystolic mg fish oil
# 1     son halfway fourth week intuniv become concern...
# 2     use take another oral contraceptive pill cycle...
# 3     suboxone completely turn life around feel heal...
# 4     day start work rock hard erection however expe...
# 5     pill many year doctor change rx chateal effect...
# 6     take anti-depressants year improvement mostly ...
# 7     take amitriptyline since january diagnose fibr...
# 8     every medicine sun seem manage hypomania mania...
# 9     spring hospitalize pnuemonia diagnose lyme die...
# 10    live western australia disturb comment cost em...
# 11    week zoloft anxiety mood swing take morning br...
# 12    similar experience tremor hand really noticeab...
# 13    prone yeast infection believe due birth contro...
# 14    medication change life panic attack control ba...
# 15    take medicine due low back trouble first take ...
# 16    gp start venlafaxine yesterday help depression...
# 17    side effect light fatigue bit headache find ea...
# 18    help sadness strongly counter moderate urge dr...
# 19    pain management doctor put butrans patch week ...
# Name: review_by_patient, dtype: object

# %%
test["review_by_patient"] = test["review_by_patient"].apply(lambda x: clean_text(x))

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
train["sentiments"] = train["review_by_patient"].apply(lambda x: sid.polarity_scores(x))
test["sentiments"] = test["review_by_patient"].apply(lambda x: sid.polarity_scores(x))

# reviews_df = pd.concat([reviews_df.drop(['sentiments'], axis=1), reviews_df['sentiments'].apply(pd.Series)], axis=1)

# %%
train.sentiments[123]
# Out:
# {'neg': 0.098, 'neu': 0.749, 'pos': 0.153, 'compound': 0.5859}

# %%
train['neg_sentiment'] = train.sentiments.apply(lambda x:round(x['neg']))
train['pos_sentiment'] = train.sentiments.apply(lambda x:round(x['pos']))
train['neu_sentimant'] = train.sentiments.apply(lambda x:round(x['neu']))

test['neg_sentiment'] = test.sentiments.apply(lambda x:round(x['neg']))
test['pos_sentiment'] = test.sentiments.apply(lambda x:round(x['pos']))
test['neu_sentimant'] = test.sentiments.apply(lambda x:round(x['neu']))

# %%
train.head()
# Out:
#    patient_id              name_of_drug             use_case_for_drug  \
# 0      206461                 Valsartan  Left Ventricular Dysfunction
# 1       95260                Guanfacine                          ADHD
# 2       92703                    Lybrel                 Birth Control
# 3       35696  Buprenorphine / naloxone             Opiate Dependence
# 4      155963                    Cialis  Benign Prostatic Hyperplasia
#
#                                    review_by_patient  effectiveness_rating  \
# 0  side effect take combination bystolic mg fish oil                     9
# 1  son halfway fourth week intuniv become concern...                     8
# 2  use take another oral contraceptive pill cycle...                     5
# 3  suboxone completely turn life around feel heal...                     9
# 4  day start work rock hard erection however expe...                     2
#
#   drug_approved_by_UIC  number_of_times_prescribed  base_score  \
# 0            20-May-12                          27    8.022969
# 1            27-Apr-10                         192    7.858458
# 2            14-Dec-09                          17    6.341969
# 3            27-Nov-16                          37    6.590176
# 4            28-Nov-15                          43    6.144782
#
#    new_effect_score                                         sentiments  \
# 0                 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1                 2  {'neg': 0.035, 'neu': 0.767, 'pos': 0.198, 'co...
# 2                 1  {'neg': 0.044, 'neu': 0.822, 'pos': 0.134, 'co...
# 3                 3  {'neg': 0.119, 'neu': 0.582, 'pos': 0.299, 'co...
# 4                 0  {'neg': 0.265, 'neu': 0.593, 'pos': 0.143, 'co...
#
#    neg_sentiment  pos_sentiment  neu_sentimant
# 0              0              0              1
# 1              0              0              1
# 2              0              0              1
# 3              0              0              1
# 4              0              0              1

# %%
feat = train.columns.to_list()
target='base_score'
delete = ['patient_id','name_of_drug','use_case_for_drug','review_by_patient','drug_approved_by_UIC',target,'sentiments','neg_sentiment','neu_sentimant']
for i in delete:
    feat.remove(i)
# print(feat)

# %% [markdown]
# # train.corr()

# %%
feat
# Out:
# ['effectiveness_rating',
#  'number_of_times_prescribed',
#  'new_effect_score',
#  'pos_sentiment']

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
X=scalar.fit_transform(train[feat])
Y = train[target].values.reshape(-1,1)

# %%
def baseliner(X,Y):
    print("Baseliner Models(All)")
    eval_dict = {}
    models = [
#         KNeighborsRegressor(), GaussianNB(), 
        lgb.LGBMRegressor(), ExtraTreesRegressor(), xgb.XGBRegressor(objective='reg:squarederror'), 
        cat.CatBoostRegressor(verbose=0), GradientBoostingRegressor(), RandomForestRegressor(), 
        LinearRegression(), DecisionTreeRegressor(), ExtraTreeRegressor(), AdaBoostRegressor(), 
#         BaggingRegressor(), ElasticNet(), Lasso(), Ridge(),SVR(),
        ]  

    print("sklearn Model Name  \t  rmse")
    print("--" * 50)
    x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=42)
    for i in models:
        model = i
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        model_name =str(i).split("(")[0]
        result=np.sqrt(mse(y_test,y_pred))
        print(f"{model_name} \t {result}")
baseliner(train[feat],train[target])
# Out:
# Baseliner Models(All)
# sklearn Model Name  	  rmse
# ----------------------------------------------------------------------------------------------------
# LGBMRegressor 	 0.20095215267981803
# ExtraTreesRegressor 	 0.19310322863797083
# XGBRegressor 	 0.1036262445166938
# <catboost.core.CatBoostRegressor object at 0x000001A6D7F042C8> 	 0.14358626563831595
# GradientBoostingRegressor 	 0.5546314616331539
# RandomForestRegressor 	 0.1711878573628764
# LinearRegression 	 1.4436469542039967
# DecisionTreeRegressor 	 0.17394073455557982
# ExtraTreeRegressor 	 0.22339642329709558
# AdaBoostRegressor 	 1.1388632270524481

# %% [markdown]
# ## Hyperopt for Better Parameters

# %%
from hyperopt import hp
import numpy as np
from sklearn.metrics import mean_squared_error


# XGB parameters
xgb_reg_params = {
    'learning_rate':    hp.choice('learning_rate',    np.arange(0.05, 0.31, 0.05)),
    'max_depth':        hp.choice('max_depth',        np.arange(5, 16, 1, dtype=int)),
    'min_child_weight': hp.choice('min_child_weight', np.arange(1, 8, 1, dtype=int)),
    'colsample_bytree': hp.choice('colsample_bytree', np.arange(0.3, 0.8, 0.1)),
    'subsample':        hp.uniform('subsample', 0.8, 1),
    'n_estimators':     500,
}
xgb_fit_params = {
    'eval_metric': 'rmse',
    'early_stopping_rounds': 10,
    'verbose': False
}
xgb_para = dict()
xgb_para['reg_params'] = xgb_reg_params
xgb_para['fit_params'] = xgb_fit_params
xgb_para['loss_func' ] = lambda y, pred: np.sqrt(mean_squared_error(y, pred))

# LightGBM parameters
lgb_reg_params = {
    'learning_rate':    hp.choice('learning_rate',    np.arange(0.05, 0.31, 0.05)),
    'max_depth':        hp.choice('max_depth',        np.arange(5, 16, 1, dtype=int)),
    'min_child_weight': hp.choice('min_child_weight', np.arange(1, 8, 1, dtype=int)),
    'colsample_bytree': hp.choice('colsample_bytree', np.arange(0.3, 0.8, 0.1)),
    'subsample':        hp.uniform('subsample', 0.8, 1),
    'n_estimators':     100,
}
lgb_fit_params = {
    'eval_metric': 'l2',
    'early_stopping_rounds': 10,
    'verbose': False
}
lgb_para = dict()
lgb_para['reg_params'] = lgb_reg_params
lgb_para['fit_params'] = lgb_fit_params
lgb_para['loss_func' ] = lambda y, pred: np.sqrt(mean_squared_error(y, pred))


# CatBoost parameters
ctb_reg_params = {
    'learning_rate':     hp.choice('learning_rate',     np.arange(0.05, 0.31, 0.05)),
    'max_depth':         hp.choice('max_depth',         np.arange(5, 16, 1, dtype=int)),
    'colsample_bylevel': hp.choice('colsample_bylevel', np.arange(0.3, 0.8, 0.1)),
    'n_estimators':      100,
    'eval_metric':       'RMSE',
}
ctb_fit_params = {
    'early_stopping_rounds': 10,
    'verbose': False
}
ctb_para = dict()
ctb_para['reg_params'] = ctb_reg_params
ctb_para['fit_params'] = ctb_fit_params
ctb_para['loss_func' ] = lambda y, pred: np.sqrt(mean_squared_error(y, pred))

# %%
import lightgbm as lgb
import xgboost as xgb
import catboost as ctb
from hyperopt import fmin, tpe, STATUS_OK, STATUS_FAIL, Trials


class HPOpt(object):

    def __init__(self, x_train, x_test, y_train, y_test):
        self.x_train = x_train
        self.x_test  = x_test
        self.y_train = y_train
        self.y_test  = y_test

    def process(self, fn_name, space, trials, algo, max_evals):
        fn = getattr(self, fn_name)
        try:
            result = fmin(fn=fn, space=space, algo=algo, max_evals=max_evals, trials=trials)
        except Exception as e:
            return {'status': STATUS_FAIL,
                    'exception': str(e)}
        return result, trials

    def xgb_reg(self, para):
        reg = xgb.XGBRegressor(**para['reg_params'])
        return self.train_reg(reg, para)

    def lgb_reg(self, para):
        reg = lgb.LGBMRegressor(**para['reg_params'])
        return self.train_reg(reg, para)

    def ctb_reg(self, para):
        reg = ctb.CatBoostRegressor(**para['reg_params'])
        return self.train_reg(reg, para)

    def train_reg(self, reg, para):
        reg.fit(self.x_train, self.y_train,
                eval_set=[(self.x_train, self.y_train), (self.x_test, self.y_test)],
                **para['fit_params'])
        pred = reg.predict(self.x_test)
        loss = para['loss_func'](self.y_test, pred)
        return {'loss': loss, 'status': STATUS_OK}

# %%
x_train, x_test, y_train, y_test = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)
obj = HPOpt(x_train, x_test, y_train, y_test)
xgb_opt = obj.process(fn_name='xgb_reg', space=xgb_para, trials=Trials(), algo=tpe.suggest, max_evals=200)
lgb_opt = obj.process(fn_name='lgb_reg', space=lgb_para, trials=Trials(), algo=tpe.suggest, max_evals=200)
ctb_opt = obj.process(fn_name='ctb_reg', space=ctb_para, trials=Trials(), algo=tpe.suggest, max_evals=200)
# Out:
# 100%|█████████████████████████████████████████████| 200/200 [32:54<00:00,  9.87s/trial, best loss: 0.05842752712071854]
# 100%|██████████████████████████████████████████████| 200/200 [01:25<00:00,  2.34trial/s, best loss: 0.1365011603104747]
# 100%|█████████████████████████████████████████████| 200/200 [17:42<00:00,  5.31s/trial, best loss: 0.16961654803230422]

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import StackingRegressor
# Creating First Layer
base_learners = [
    ('lgbm',lgb.LGBMRegressor(boosting_type='gbdt',
                        num_leaves=300,
                        max_depth=16,
                        learning_rate = 0.5,
                        n_estimators=400,
                         subsample_for_bin=200000,
#                          class_weight=,
#                          min_split_gain=0.01,
#                          min_child_weight=0.1,
                         objective=None,
                         min_child_samples=20,
                         subsample=1.0,
                         subsample_freq=0,
                         colsample_bytree=1.0,
                         reg_alpha=0.0,
                         reg_lambda=0.0,
                         random_state=None,
                         n_jobs=-1,
                         silent=True
                        )),
]
# Initializating Stacking Regressor with the meta lerner
reg = StackingRegressor(estimators=base_learners,final_estimator=xgb.XGBRegressor(objective='reg:squarederror',n_estimators=500,max_depth=8,learning_rate=0.25,colsample_bytree=0.7,min_child_weight=1,subsample=0.8862306230110487))
train_X, test_X, train_y, test_y = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)
reg.fit(train_X,train_y)
y_pred = reg.predict(test_X)
print(np.sqrt(mse(test_y,y_pred)))
# Out:
# 0.14793464715512536

# %%
lgbm = lgb.LGBMRegressor(boosting_type='gbdt',
                        num_leaves=300,
                        max_depth=16,
                        learning_rate = 0.5,
                        n_estimators=400,
                         subsample_for_bin=200000,
#                          class_weight=,
#                          min_split_gain=0.01,
#                          min_child_weight=0.1,
                         objective=None,
                         min_child_samples=20,
                         subsample=1.0,
                         subsample_freq=0,
                         colsample_bytree=1.0,
                         reg_alpha=0.0,
                         reg_lambda=0.0,
                         random_state=None,
                         n_jobs=-1,
                         silent=True
                        )
lgbm.fit(train[feat],train[target])
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.5, max_depth=16,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=400, n_jobs=-1, num_leaves=300, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
train_X, test_X, train_y, test_y = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)
y_pred = lgbm.predict(test_X)
print(np.sqrt(mse(test_y,y_pred)))
# Out:
# 0.03915048577402916

# %%
train_X, test_X, train_y, test_y = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)

my_model = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=500,max_depth=8,learning_rate=0.25,colsample_bytree=0.7,min_child_weight=1,subsample=0.8862306230110487)
my_model.fit(train[feat],train[target],early_stopping_rounds=10, eval_set=[(test_X, test_y)], verbose=1)
y_pred = my_model.predict(test_X)
print(np.sqrt(mse(test_y,y_pred)))
# Out:
# [0]	validation_0-rmse:4.82599
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:3.68795
# [2]	validation_0-rmse:2.84024
# [3]	validation_0-rmse:2.18944
# [4]	validation_0-rmse:1.73568
# [5]	validation_0-rmse:1.38516
# [6]	validation_0-rmse:1.16546
# [7]	validation_0-rmse:1.02174
# [8]	validation_0-rmse:0.93151
# [9]	validation_0-rmse:0.84178
# [10]	validation_0-rmse:0.79093
# [11]	validation_0-rmse:0.71328
# [12]	validation_0-rmse:0.69459
# [13]	validation_0-rmse:0.68746
# [14]	validation_0-rmse:0.68002
# [15]	validation_0-rmse:0.64559
# [16]	validation_0-rmse:0.64253
# [17]	validation_0-rmse:0.64086
# [18]	validation_0-rmse:0.60196
# [19]	validation_0-rmse:0.53856
# [20]	validation_0-rmse:0.52736
# [21]	validation_0-rmse:0.52660
# [22]	validation_0-rmse:0.52622
# [23]	validation_0-rmse:0.48393
# [24]	validation_0-rmse:0.44834
# [25]	validation_0-rmse:0.43910
# [26]	validation_0-rmse:0.43906
# [27]	validation_0-rmse:0.43881
# [28]	validation_0-rmse:0.43867
# [29]	validation_0-rmse:0.40644
# [30]	validation_0-rmse:0.39365
# [31]	validation_0-rmse:0.39365
# [32]	validation_0-rmse:0.39361
# [33]	validation_0-rmse:0.37040
# [34]	validation_0-rmse:0.37040
# [35]	validation_0-rmse:0.35086
# [36]	validation_0-rmse:0.34259
# [37]	validation_0-rmse:0.31780
# [38]	validation_0-rmse:0.31775
# [39]	validation_0-rmse:0.29981
# [40]	validation_0-rmse:0.28627
# [41]	validation_0-rmse:0.26822
# [42]	validation_0-rmse:0.26822
# [43]	validation_0-rmse:0.26821
# [44]	validation_0-rmse:0.25335
# [45]	validation_0-rmse:0.24717
# [46]	validation_0-rmse:0.24715
# [47]	validation_0-rmse:0.24715
# [48]	validation_0-rmse:0.24306
# [49]	validation_0-rmse:0.23715
# [50]	validation_0-rmse:0.23716
# [51]	validation_0-rmse:0.23373
# [52]	validation_0-rmse:0.23370
# [53]	validation_0-rmse:0.22222
# [54]	validation_0-rmse:0.22221
# [55]	validation_0-rmse:0.22220
# [56]	validation_0-rmse:0.22220
# [57]	validation_0-rmse:0.22220
# [58]	validation_0-rmse:0.22220
# [59]	validation_0-rmse:0.21521
# [60]	validation_0-rmse:0.21164
# [61]	validation_0-rmse:0.21163
# [62]	validation_0-rmse:0.21164
# [63]	validation_0-rmse:0.21164
# [64]	validation_0-rmse:0.20358
# [65]	validation_0-rmse:0.20358
# [66]	validation_0-rmse:0.19603
# [67]	validation_0-rmse:0.19603
# [68]	validation_0-rmse:0.19604
# [69]	validation_0-rmse:0.19603
# [70]	validation_0-rmse:0.19603
# [71]	validation_0-rmse:0.19604
# [72]	validation_0-rmse:0.19603
# [73]	validation_0-rmse:0.19603
# [74]	validation_0-rmse:0.19603
# [75]	validation_0-rmse:0.19182
# [76]	validation_0-rmse:0.19182
# [77]	validation_0-rmse:0.19183
# [78]	validation_0-rmse:0.18600
# [79]	validation_0-rmse:0.18600
# [80]	validation_0-rmse:0.18599
# [81]	validation_0-rmse:0.18599
# [82]	validation_0-rmse:0.18599
# [83]	validation_0-rmse:0.18599
# [84]	validation_0-rmse:0.18358
# [85]	validation_0-rmse:0.18358
# [86]	validation_0-rmse:0.17825
# [87]	validation_0-rmse:0.17825
# [88]	validation_0-rmse:0.17205
# [89]	validation_0-rmse:0.17206
# [90]	validation_0-rmse:0.16555
# [91]	validation_0-rmse:0.16238
# [92]	validation_0-rmse:0.16237
# [93]	validation_0-rmse:0.16237
# [94]	validation_0-rmse:0.16237
# [95]	validation_0-rmse:0.16164
# [96]	validation_0-rmse:0.16164
# [97]	validation_0-rmse:0.16164
# [98]	validation_0-rmse:0.15929
# [99]	validation_0-rmse:0.15585
# [100]	validation_0-rmse:0.15584
# [101]	validation_0-rmse:0.15584
# [102]	validation_0-rmse:0.15584
# [103]	validation_0-rmse:0.15331
# [104]	validation_0-rmse:0.14759
# [105]	validation_0-rmse:0.14648
# [106]	validation_0-rmse:0.14648
# [107]	validation_0-rmse:0.14389
# [108]	validation_0-rmse:0.14389
# [109]	validation_0-rmse:0.14323
# [110]	validation_0-rmse:0.14323
# [111]	validation_0-rmse:0.14323
# [112]	validation_0-rmse:0.14210
# [113]	validation_0-rmse:0.13908
# [114]	validation_0-rmse:0.13592
# [115]	validation_0-rmse:0.13592
# [116]	validation_0-rmse:0.13468
# [117]	validation_0-rmse:0.12000
# [118]	validation_0-rmse:0.11909
# [119]	validation_0-rmse:0.11909
# [120]	validation_0-rmse:0.11909
# [121]	validation_0-rmse:0.11619
# [122]	validation_0-rmse:0.11585
# [123]	validation_0-rmse:0.11557
# [124]	validation_0-rmse:0.11363
# [125]	validation_0-rmse:0.11363
# [126]	validation_0-rmse:0.11238
# [127]	validation_0-rmse:0.11238
# [128]	validation_0-rmse:0.11239
# [129]	validation_0-rmse:0.10917
# [130]	validation_0-rmse:0.10917
# [131]	validation_0-rmse:0.10916
# [132]	validation_0-rmse:0.10806
# [133]	validation_0-rmse:0.10806
# [134]	validation_0-rmse:0.10806
# [135]	validation_0-rmse:0.10806
# [136]	validation_0-rmse:0.10780
# [137]	validation_0-rmse:0.10540
# [138]	validation_0-rmse:0.10540
# [139]	validation_0-rmse:0.10540
# [140]	validation_0-rmse:0.10501
# [141]	validation_0-rmse:0.10501
# [142]	validation_0-rmse:0.10501
# [143]	validation_0-rmse:0.10500
# [144]	validation_0-rmse:0.10441
# [145]	validation_0-rmse:0.10243
# [146]	validation_0-rmse:0.10242
# [147]	validation_0-rmse:0.10242
# [148]	validation_0-rmse:0.10242
# [149]	validation_0-rmse:0.10243
# [150]	validation_0-rmse:0.10243
# [151]	validation_0-rmse:0.10160
# [152]	validation_0-rmse:0.10066
# [153]	validation_0-rmse:0.10066
# [154]	validation_0-rmse:0.10004
# [155]	validation_0-rmse:0.10004
# [156]	validation_0-rmse:0.10004
# [157]	validation_0-rmse:0.10005
# [158]	validation_0-rmse:0.10004
# [159]	validation_0-rmse:0.10004
# [160]	validation_0-rmse:0.09809
# [161]	validation_0-rmse:0.09809
# [162]	validation_0-rmse:0.09773
# [163]	validation_0-rmse:0.09773
# [164]	validation_0-rmse:0.09773
# [165]	validation_0-rmse:0.09773
# [166]	validation_0-rmse:0.09716
# [167]	validation_0-rmse:0.09716
# [168]	validation_0-rmse:0.09716
# [169]	validation_0-rmse:0.09661
# [170]	validation_0-rmse:0.09616
# [171]	validation_0-rmse:0.09596
# [172]	validation_0-rmse:0.09573
# [173]	validation_0-rmse:0.09573
# [174]	validation_0-rmse:0.09463
# [175]	validation_0-rmse:0.09378
# [176]	validation_0-rmse:0.09345
# [177]	validation_0-rmse:0.09315
# [178]	validation_0-rmse:0.09315
# [179]	validation_0-rmse:0.09314
# [180]	validation_0-rmse:0.09267
# [181]	validation_0-rmse:0.09267
# [182]	validation_0-rmse:0.09166
# [183]	validation_0-rmse:0.09166
# [184]	validation_0-rmse:0.09166
# [185]	validation_0-rmse:0.09166
# [186]	validation_0-rmse:0.09166
# [187]	validation_0-rmse:0.09166
# [188]	validation_0-rmse:0.09166
# [189]	validation_0-rmse:0.09150
# [190]	validation_0-rmse:0.09107
# [191]	validation_0-rmse:0.09100
# [192]	validation_0-rmse:0.09005
# [193]	validation_0-rmse:0.08982
# [194]	validation_0-rmse:0.08897
# [195]	validation_0-rmse:0.08897
# [196]	validation_0-rmse:0.08879
# [197]	validation_0-rmse:0.08879
# [198]	validation_0-rmse:0.08879
# [199]	validation_0-rmse:0.08879
# [200]	validation_0-rmse:0.08879
# [201]	validation_0-rmse:0.08858
# [202]	validation_0-rmse:0.08840
# [203]	validation_0-rmse:0.08825
# [204]	validation_0-rmse:0.08825
# [205]	validation_0-rmse:0.08825
# [206]	validation_0-rmse:0.08825
# [207]	validation_0-rmse:0.08825
# [208]	validation_0-rmse:0.08825
# [209]	validation_0-rmse:0.08413
# [210]	validation_0-rmse:0.08413
# [211]	validation_0-rmse:0.08335
# [212]	validation_0-rmse:0.08325
# [213]	validation_0-rmse:0.08325
# [214]	validation_0-rmse:0.08279
# [215]	validation_0-rmse:0.08279
# [216]	validation_0-rmse:0.08225
# [217]	validation_0-rmse:0.08225
# [218]	validation_0-rmse:0.08188
# [219]	validation_0-rmse:0.08188
# [220]	validation_0-rmse:0.08188
# [221]	validation_0-rmse:0.08188
# [222]	validation_0-rmse:0.08188
# [223]	validation_0-rmse:0.08188
# [224]	validation_0-rmse:0.08173
# [225]	validation_0-rmse:0.08173
# [226]	validation_0-rmse:0.08173
# [227]	validation_0-rmse:0.08155
# [228]	validation_0-rmse:0.08137
# [229]	validation_0-rmse:0.07487
# [230]	validation_0-rmse:0.07486
# [231]	validation_0-rmse:0.07486
# [232]	validation_0-rmse:0.07486
# [233]	validation_0-rmse:0.07486
# [234]	validation_0-rmse:0.07486
# [235]	validation_0-rmse:0.07479
# [236]	validation_0-rmse:0.07468
# [237]	validation_0-rmse:0.07468
# [238]	validation_0-rmse:0.07468
# [239]	validation_0-rmse:0.07469
# [240]	validation_0-rmse:0.07428
# [241]	validation_0-rmse:0.07422
# [242]	validation_0-rmse:0.07422
# [243]	validation_0-rmse:0.07422
# [244]	validation_0-rmse:0.07422
# [245]	validation_0-rmse:0.07405
# [246]	validation_0-rmse:0.07388
# [247]	validation_0-rmse:0.07382
# [248]	validation_0-rmse:0.07363
# [249]	validation_0-rmse:0.07360
# [250]	validation_0-rmse:0.07342
# [251]	validation_0-rmse:0.07334
# [252]	validation_0-rmse:0.07334
# [253]	validation_0-rmse:0.07329
# [254]	validation_0-rmse:0.07329
# [255]	validation_0-rmse:0.07329
# [256]	validation_0-rmse:0.07305
# [257]	validation_0-rmse:0.07305
# [258]	validation_0-rmse:0.07305
# [259]	validation_0-rmse:0.07305
# [260]	validation_0-rmse:0.07305
# [261]	validation_0-rmse:0.07295
# [262]	validation_0-rmse:0.07295
# [263]	validation_0-rmse:0.07295
# [264]	validation_0-rmse:0.07287
# [265]	validation_0-rmse:0.07287
# [266]	validation_0-rmse:0.07287
# [267]	validation_0-rmse:0.07286
# [268]	validation_0-rmse:0.07287
# [269]	validation_0-rmse:0.07280
# [270]	validation_0-rmse:0.07280
# [271]	validation_0-rmse:0.07280
# [272]	validation_0-rmse:0.07274
# [273]	validation_0-rmse:0.07274
# [274]	validation_0-rmse:0.07274
# [275]	validation_0-rmse:0.07274
# [276]	validation_0-rmse:0.07269
# [277]	validation_0-rmse:0.07269
# [278]	validation_0-rmse:0.06628
# [279]	validation_0-rmse:0.06628
# [280]	validation_0-rmse:0.06628
# [281]	validation_0-rmse:0.06626
# [282]	validation_0-rmse:0.06626
# [283]	validation_0-rmse:0.06625
# [284]	validation_0-rmse:0.05962
# [285]	validation_0-rmse:0.05962
# [286]	validation_0-rmse:0.05962
# [287]	validation_0-rmse:0.05955
# [288]	validation_0-rmse:0.05839
# [289]	validation_0-rmse:0.05838
# [290]	validation_0-rmse:0.05835
# [291]	validation_0-rmse:0.05830
# [292]	validation_0-rmse:0.05831
# [293]	validation_0-rmse:0.05826
# [294]	validation_0-rmse:0.05817
# [295]	validation_0-rmse:0.05815
# [296]	validation_0-rmse:0.05815
# [297]	validation_0-rmse:0.05811
# [298]	validation_0-rmse:0.05811
# [299]	validation_0-rmse:0.05808
# [300]	validation_0-rmse:0.05802
# [301]	validation_0-rmse:0.05802
# [302]	validation_0-rmse:0.05798
# [303]	validation_0-rmse:0.05798
# [304]	validation_0-rmse:0.05795
# [305]	validation_0-rmse:0.05795
# [306]	validation_0-rmse:0.05795
# [307]	validation_0-rmse:0.05795
# [308]	validation_0-rmse:0.05794
# [309]	validation_0-rmse:0.05794
# [310]	validation_0-rmse:0.05794
# [311]	validation_0-rmse:0.05791
# [312]	validation_0-rmse:0.05364
# [313]	validation_0-rmse:0.05360
# [314]	validation_0-rmse:0.05337
# [315]	validation_0-rmse:0.05337
# [316]	validation_0-rmse:0.05337
# [317]	validation_0-rmse:0.05335
# [318]	validation_0-rmse:0.05334
# [319]	validation_0-rmse:0.05332
# [320]	validation_0-rmse:0.05323
# [321]	validation_0-rmse:0.05319
# [322]	validation_0-rmse:0.05319
# [323]	validation_0-rmse:0.05312
# [324]	validation_0-rmse:0.05312
# [325]	validation_0-rmse:0.05312
# [326]	validation_0-rmse:0.05310
# [327]	validation_0-rmse:0.05310
# [328]	validation_0-rmse:0.05277
# [329]	validation_0-rmse:0.05274
# [330]	validation_0-rmse:0.05274
# [331]	validation_0-rmse:0.05216
# [332]	validation_0-rmse:0.05215
# [333]	validation_0-rmse:0.05211
# [334]	validation_0-rmse:0.05211
# [335]	validation_0-rmse:0.05150
# [336]	validation_0-rmse:0.05145
# [337]	validation_0-rmse:0.04763
# [338]	validation_0-rmse:0.04621
# [339]	validation_0-rmse:0.04620
# [340]	validation_0-rmse:0.04617
# [341]	validation_0-rmse:0.04482
# [342]	validation_0-rmse:0.04475
# [343]	validation_0-rmse:0.04131
# [344]	validation_0-rmse:0.04131
# [345]	validation_0-rmse:0.04111
# [346]	validation_0-rmse:0.04015
# [347]	validation_0-rmse:0.04015
# [348]	validation_0-rmse:0.04015
# [349]	validation_0-rmse:0.03962
# [350]	validation_0-rmse:0.03962
# [351]	validation_0-rmse:0.03768
# [352]	validation_0-rmse:0.03767
# [353]	validation_0-rmse:0.03767
# [354]	validation_0-rmse:0.03762
# [355]	validation_0-rmse:0.03763
# [356]	validation_0-rmse:0.03763
# [357]	validation_0-rmse:0.03760
# [358]	validation_0-rmse:0.03697
# [359]	validation_0-rmse:0.03697
# [360]	validation_0-rmse:0.03697
# [361]	validation_0-rmse:0.03697
# [362]	validation_0-rmse:0.03664
# [363]	validation_0-rmse:0.03664
# [364]	validation_0-rmse:0.03664
# [365]	validation_0-rmse:0.03664
# [366]	validation_0-rmse:0.03654
# [367]	validation_0-rmse:0.03653
# [368]	validation_0-rmse:0.03651
# [369]	validation_0-rmse:0.03650
# [370]	validation_0-rmse:0.03649
# [371]	validation_0-rmse:0.03648
# [372]	validation_0-rmse:0.03646
# [373]	validation_0-rmse:0.03646
# [374]	validation_0-rmse:0.03646
# [375]	validation_0-rmse:0.03646
# [376]	validation_0-rmse:0.03578
# [377]	validation_0-rmse:0.03454
# [378]	validation_0-rmse:0.03453
# [379]	validation_0-rmse:0.03453
# [380]	validation_0-rmse:0.03453
# [381]	validation_0-rmse:0.03233
# [382]	validation_0-rmse:0.03092
# [383]	validation_0-rmse:0.03092
# [384]	validation_0-rmse:0.03092
# [385]	validation_0-rmse:0.03091
# [386]	validation_0-rmse:0.03091
# [387]	validation_0-rmse:0.03089
# [388]	validation_0-rmse:0.03084
# [389]	validation_0-rmse:0.03063
# [390]	validation_0-rmse:0.03063
# [391]	validation_0-rmse:0.03063
# [392]	validation_0-rmse:0.03063
# [393]	validation_0-rmse:0.03061
# [394]	validation_0-rmse:0.02965
# [395]	validation_0-rmse:0.02898
# [396]	validation_0-rmse:0.02898
# [397]	validation_0-rmse:0.02898
# [398]	validation_0-rmse:0.02898
# [399]	validation_0-rmse:0.02898
# [400]	validation_0-rmse:0.02896
# [401]	validation_0-rmse:0.02879
# [402]	validation_0-rmse:0.02877
# [403]	validation_0-rmse:0.02876
# [404]	validation_0-rmse:0.02876
# [405]	validation_0-rmse:0.02876
# [406]	validation_0-rmse:0.02876
# [407]	validation_0-rmse:0.02781
# [408]	validation_0-rmse:0.02781
# [409]	validation_0-rmse:0.02781
# [410]	validation_0-rmse:0.02782
# [411]	validation_0-rmse:0.02782
# [412]	validation_0-rmse:0.02782
# [413]	validation_0-rmse:0.02632
# [414]	validation_0-rmse:0.02622
# [415]	validation_0-rmse:0.02622
# [416]	validation_0-rmse:0.02619
# [417]	validation_0-rmse:0.02619
# [418]	validation_0-rmse:0.02612
# [419]	validation_0-rmse:0.02612
# [420]	validation_0-rmse:0.02608
# [421]	validation_0-rmse:0.02595
# [422]	validation_0-rmse:0.02595
# [423]	validation_0-rmse:0.02595
# [424]	validation_0-rmse:0.02585
# [425]	validation_0-rmse:0.02582
# [426]	validation_0-rmse:0.02582
# [427]	validation_0-rmse:0.02582
# [428]	validation_0-rmse:0.02579
# [429]	validation_0-rmse:0.02579
# [430]	validation_0-rmse:0.02579
# [431]	validation_0-rmse:0.02578
# [432]	validation_0-rmse:0.02578
# [433]	validation_0-rmse:0.02578
# [434]	validation_0-rmse:0.02576
# [435]	validation_0-rmse:0.02418
# [436]	validation_0-rmse:0.02418
# [437]	validation_0-rmse:0.02416
# [438]	validation_0-rmse:0.02416
# [439]	validation_0-rmse:0.02408
# [440]	validation_0-rmse:0.02383
# [441]	validation_0-rmse:0.02383
# [442]	validation_0-rmse:0.02383
# [443]	validation_0-rmse:0.02382
# [444]	validation_0-rmse:0.02380
# [445]	validation_0-rmse:0.02380
# [446]	validation_0-rmse:0.02380
# [447]	validation_0-rmse:0.02257
# [448]	validation_0-rmse:0.02257
# [449]	validation_0-rmse:0.02256
# [450]	validation_0-rmse:0.02252
# [451]	validation_0-rmse:0.02252
# [452]	validation_0-rmse:0.02252
# [453]	validation_0-rmse:0.02248
# [454]	validation_0-rmse:0.02249
# [455]	validation_0-rmse:0.02248
# [456]	validation_0-rmse:0.02248
# [457]	validation_0-rmse:0.02248
# [458]	validation_0-rmse:0.02248
# [459]	validation_0-rmse:0.02248
# [460]	validation_0-rmse:0.02248
# [461]	validation_0-rmse:0.02247
# [462]	validation_0-rmse:0.02177
# [463]	validation_0-rmse:0.02169
# [464]	validation_0-rmse:0.02169
# [465]	validation_0-rmse:0.02169
# [466]	validation_0-rmse:0.02169
# [467]	validation_0-rmse:0.02110
# [468]	validation_0-rmse:0.02110
# [469]	validation_0-rmse:0.02110
# [470]	validation_0-rmse:0.02110
# [471]	validation_0-rmse:0.02110
# [472]	validation_0-rmse:0.02104
# [473]	validation_0-rmse:0.02103
# [474]	validation_0-rmse:0.02081
# [475]	validation_0-rmse:0.02081
# [476]	validation_0-rmse:0.02075
# [477]	validation_0-rmse:0.02074
# [478]	validation_0-rmse:0.02030
# [479]	validation_0-rmse:0.02029
# [480]	validation_0-rmse:0.02029
# [481]	validation_0-rmse:0.02029
# [482]	validation_0-rmse:0.02028
# [483]	validation_0-rmse:0.02023
# [484]	validation_0-rmse:0.02023
# [485]	validation_0-rmse:0.02023
# [486]	validation_0-rmse:0.02023
# [487]	validation_0-rmse:0.02023
# [488]	validation_0-rmse:0.02023
# [489]	validation_0-rmse:0.02023
# [490]	validation_0-rmse:0.02023
# [491]	validation_0-rmse:0.02023
# [492]	validation_0-rmse:0.02023
# [493]	validation_0-rmse:0.02023
# [494]	validation_0-rmse:0.01966
# [495]	validation_0-rmse:0.01966
# [496]	validation_0-rmse:0.01939
# [497]	validation_0-rmse:0.01939
# [498]	validation_0-rmse:0.01939
# [499]	validation_0-rmse:0.01939
# 0.019392334259919285

# %%
y_pred = my_model.predict(test[feat])
ans=[]
for i in range(len(y_pred)):
    ans.append(round(y_pred[i],2))
sub = test['patient_id']
sub = pd.DataFrame(sub)
sub['base_score']=ans

# %%
#Creating Link in Kaggle
from IPython.display import HTML
import pandas as pd
import numpy as np
import base64

def create_download_link(df, title = "Download CSV file", filename = "std_20.csv"):  
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(sub)
# Out:
# <a download="std_20.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
